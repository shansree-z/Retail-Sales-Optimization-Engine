# %% [markdown]
# <a href="https://colab.research.google.com/github/shansree-z/Retail-Sales-Optimization-Engine/blob/main/Retail_Sales_Optimization_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abhishekjaiswal4896/store-sales-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/abhishekjaiswal4896/store-sales-dataset?dataset_version_number=1...
# 100%|██████████| 41.9k/41.9k [00:00<00:00, 36.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/abhishekjaiswal4896/store-sales-dataset/versions/1

# %%
import pandas as pd
import kagglehub
import os

path = kagglehub.dataset_download("abhishekjaiswal4896/store-sales-dataset")
csv_path = os.path.join(path, "store_sales.csv")

df = pd.read_csv(csv_path)
arr = df['sales'].tolist()
max_sum = 5000

def find_best_window(arr, max_sum):
    left = 0
    current_sum = 0
    best = 0
    best_nums = []

    for right in range(len(arr)):
        current_sum += arr[right]

        while current_sum > max_sum:
            current_sum -= arr[left]
            left += 1

        if current_sum > best:
            best = current_sum
            best_nums = arr[left:right+1]

    return best, best_nums

best_sum, numbers = find_best_window(arr, max_sum)

print(f"the maximum is {best_sum}")
print(f"Numbers: {numbers}")
print(f"As string: {'+'.join(str(x) for x in numbers)}")
# Out:
# Using Colab cache for faster access to the 'store-sales-dataset' dataset.
# the maximum is 4999.9999999999945
# Numbers: [202.24, 195.96, 202.03, 226.36, 224.02, 241.29, 229.59, 203.52, 197.66, 228.27, 217.17, 239.48, 238.87, 227.62, 205.62, 189.58, 199.87, 222.63, 224.65, 230.92, 226.06, 233.2, 193.39]
# As string: 202.24+195.96+202.03+226.36+224.02+241.29+229.59+203.52+197.66+228.27+217.17+239.48+238.87+227.62+205.62+189.58+199.87+222.63+224.65+230.92+226.06+233.2+193.39
